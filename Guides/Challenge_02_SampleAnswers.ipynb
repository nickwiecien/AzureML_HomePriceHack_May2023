# %% [markdown]
# ## Connect to Azure ML Workspace using the AML SDK
# The code snippet below retrieves a reference to your AML workspace - you can interact directly with resources in your workspace via the SDK, similar to how you can use the Studio UI.

# %%
from azureml.core import Workspace

ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# textron-aml-live
# textron-mlops-hack-rg
# eastus
# 3a72b9f9-cb8d-44de-827e-ade93ff2dab5

# %% [markdown]
# ## Load & Review Dataset
# Update the code snippet below to retrieve your dataset from the workspace by name and display as a pandas dataframe. <i>Note:</i> If you get stuck, take a look at your dataset in the AML Studio UI and review the constent under the `Consume` tab.

# %%
from azureml.core import Dataset

# TO-DO:
# - Update the variable called `dataset_name` to the name of the dataset you created in the AML studio
# - Uncomment and update the dataset syntax below 
dataset_name = "NWK-HOME-PRICE-DATA"
aml_dataset = Dataset.get_by_name(ws, dataset_name)

aml_dataframe = aml_dataset.to_pandas_dataframe()

aml_dataframe.head(10)
# Out:
#        CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0   8.15174  0.0  18.10     0  0.700  5.390  98.9  1.7281   24  666     20.2
# 1  10.23300  0.0  18.10     0  0.614  6.185  96.7  2.1705   24  666     20.2
# 2  24.80170  0.0  18.10     0  0.693  5.349  96.0  1.7028   24  666     20.2
# 3   0.25199  0.0  10.59     0  0.489  5.783  72.7  4.3549    4  277     18.6
# 4   0.20746  0.0  27.74     0  0.609  5.093  98.0  1.8226    4  711     20.1
# 5   0.26938  0.0   9.90     0  0.544  6.266  82.8  3.2628    4  304     18.4
# 6   4.64689  0.0  18.10     0  0.614  6.980  67.6  2.5329   24  666     20.2
# 7   1.65660  0.0  19.58     0  0.871  6.122  97.3  1.6180    5  403     14.7
# 8   2.24236  0.0  19.58     0  0.605  5.854  91.8  2.4220    5  403     14.7
# 9   0.12083  0.0   2.89     0  0.445  8.069  76.0  3.4952    2  276     18.0
#
#    LSTAT  MEDV
# 0  20.85  11.5
# 1  18.03  14.6
# 2  19.77   8.3
# 3  18.06  22.5
# 4  29.68   8.1
# 5   7.90  21.6
# 6  11.66  29.8
# 7  14.10  21.5
# 8  11.64  22.7
# 9   4.21  38.7
